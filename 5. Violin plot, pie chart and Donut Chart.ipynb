# %% [markdown]
# # DS Fundamentals: Categorical and Distribution Plots
#
# This notebook is part of the `DS-Fundamentals` repository and demonstrates violin plots, pie charts, and donut charts using Matplotlib.
#
# You will learn how to:
# - visualize category-based distributions with violin plots
# - create pie charts for proportional data
# - design donut charts for improved presentation
# - customize chart labels, colors, and annotations

# %% [markdown]
# # **Violin Plot**

# %%
import matplotlib.pyplot as plt

# %%
one=[1,2,3,4,5,6,7,8,9]
two=[1,2,3,4,5,4,3,2,1]
three=[6,7,8,9,8,7,6,5,4]
data=list([one,two,three])
plt.violinplot(data, showmedians=True)
plt.show()

# %% [markdown]
# # **Pie charts**

# %%
Fruits=["apple","Mangos","Banana","Litchi","Orange"]
quantity=[53,43,12,97,80]
plt.pie(quantity,labels=Fruits)
plt.show()

# %% [markdown]
# ## **Changing asthetics**

# %%
import matplotlib.pyplot as plt

Fruits = ["apple", "Mangos", "Banana", "Litchi", "Orange"]
quantity = [53, 43, 12, 97, 80]

plt.pie(quantity, labels=Fruits, autopct="%0.1f%%", colors=["green", "yellow", "red", "orange", "pink"])
plt.show()

# %% [markdown]
# # **Donut Chart**

# %%
Fruits = ["apple", "Mangos", "Banana", "Litchi", "Orange"]
quantity = [53, 43, 12, 97, 80]

# %%
plt.pie(quantity, labels=Fruits, autopct="%0.1f%%", colors=["green", "yellow", "red", "orange", "pink"], radius=2)
plt.pie([5],colors="w",radius=1)
plt.show()
