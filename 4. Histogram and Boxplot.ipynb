# %% [markdown]
# # DS Fundamentals: Histogram and Boxplot Visualization
#
# This notebook is part of the `DS-Fundamentals` repository and demonstrates distribution analysis using histograms and boxplots.
#
# You will learn how to:
# - visualize data distributions with histograms
# - adjust bin sizes for clearer insights
# - analyze real-world dataset features
# - compare distributions using boxplots

# %% [markdown]
# # **Making Histogram**

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data=[1,3,3,3,3,9,9,4,4,8,8,8,6,7]   #creating a data

# %%
plt.hist(data)   # Plotting a histogram with hist function
plt.show()

# %% [markdown]
# ## **Adding with the bins**

# %%
plt.hist(data, color="b", bins=3)   # Plotting a histogram with hist function and that bins only make the three box bins if bins=5 there there will be 5 boxes
plt.show()

# %% [markdown]
# # **Working with a real world data**

# %%
import pandas as pd

# %%
iris_df=pd.read_csv('/content/drive/MyDrive/Collab Notebook/Python Libraries for Machine Learning/Matplotlib Basics/Data/iris.csv')

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
plt.subplot(1,4,1)
plt.hist(iris_df['sepal_length'],bins=30,color="g")

plt.subplot(1,4,2)
plt.hist(iris_df['petal_length'],bins=30,color="r")

plt.subplot(1,4,3)
plt.hist(iris_df['sepal_width'],bins=30,color="b")

plt.subplot(1,4,4)
plt.hist(iris_df['petal_width'],bins=30,color="y")
plt.show()

# %% [markdown]
# # **Creating a Box plot**

# %%
one=[1,2,3,4,5,6,7,8,9]
two=[1,2,3,4,5,4,3,2,1]
three=[6,7,8,9,8,7,6,5,4]
data=list([one,two,three])
plt.boxplot(data)
plt.show()
